# %%
import folium

# %%
istanbul = folium.Map(location=[41.045764, 29.017043], zoom_start=10, tiles = "stamentoner")

# %%
istanbul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
istanbul.save("istanbul.html")

# %%
import os

# %%
data = os.path.join("a.json")

# %%
folium.GeoJson(data, name = "libraries").add_to(istanbul)

# %%
istanbul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins 
from folium.plugins import HeatMap

# %%
HeatMap(data).add_to(folium.FeatureGroup(name = "Heat Map").add_to(istanbul))
folium.LayerControl().add_to(istanbul)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-55b71b26130e> in <module>
# ----> 1 HeatMap(a).add_to(folium.FeatureGroup(name = "Heat Map").add_to(istanbul))
#       2 folium.LayerControl().add_to(istanbul)
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\folium\plugins\heat_map.py in __init__(self, data, name, min_opacity, max_zoom, max_val, radius, blur, gradient, overlay, control, show, **kwargs)
#      65         data = if_pandas_df_convert_to_numpy(data)
#      66         self.data = [[*validate_location(line[:2]), *line[2:]]  # noqa: E999
# ---> 67                      for line in data]
#      68         if np.any(np.isnan(self.data)):
#      69             raise ValueError('data may not contain NaNs.')
#
# TypeError: 'GeoJson' object is not iterable

# %%
print(data)
# Out:
# a.json

# %%
import geojson
with open("a.json") as f:
    gj = geojson.load(f)
features = gj['features'][0]

# %%
need = features["geometry"]
need
features
# Out:
# {"geometry": {"coordinates": [[[28.950078, 41.016988], [28.950145, 41.017038], [28.949904, 41.017219], [28.949622, 41.01701], [28.949925, 41.016796], [28.950069, 41.016916], [28.950078, 41.016988]], [[28.949731, 41.017057], [28.949828, 41.017122], [28.949956, 41.017014], [28.949859, 41.016949], [28.949731, 41.017057]]], "type": "Polygon"}, "id": "relation/7604178", "properties": {"@id": "relation/7604178", "addr:city": "\u0130stanbul", "addr:district": "Fatih", "amenity": "library", "building": "yes", "name": "Millet Yazma Eser K\u00fct\u00fcphanesi", "name:ar": "????? ?????", "name:en": "Millet Manuscript Library", "phone": "02126313607", "type": "multipolygon", "wheelchair": "no"}, "type": "Feature"}

# %%
from folium import plugins
from folium.plugins import HeatMap

# %%
HeatMap(need).add_to(folium.FeatureGroup(name = "HeatMap").add_to(istanbul))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\folium\utilities.py in validate_location(location)
#      58         try:
# ---> 59             float(coord)
#      60         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: 't'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-feeb3c20cebf> in <module>
# ----> 1 HeatMap(need).add_to(folium.FeatureGroup(name = "HeatMap").add_to(istanbul))
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\folium\plugins\heat_map.py in __init__(self, data, name, min_opacity, max_zoom, max_val, radius, blur, gradient, overlay, control, show, **kwargs)
# ...
